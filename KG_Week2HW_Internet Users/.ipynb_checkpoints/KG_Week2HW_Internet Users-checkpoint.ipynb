# %%
#Compare the number of internet users in different countries.
#What is the growth rate of internet users in the countries across the world.
#The values in this data show number of internet users per 100 of the populaiton of that country or region.

# %%
import pandas as pd
import numpy as np

# %%
#data = pd.read_csv("internet_data_2.csv")
#data.head()

# %%
#data.describe()

# %%
#print data

# %%
#import pandas as pd
#datatest1 = pd.read_csv("internet_data.csv")
#datatest1.head()

# %%
#data.info()

# %%
#data includes 249 rows of country names, but only 248 of those country names have country codes.
#find the CountryName with the missing CountryCode and add a countrycode to that row.

# %%
data[data.CountryCode.isnull()]
# Out:
#     CountryName CountryCode  1991  1992  1993  1994  1995  1996  1997  1998  \
# 117      Kosovo         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      ...   2005  2006  2007  2008  2009  2010  2011  2012  2013  2014
# 117  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 26 columns]

# %%
#Kosovo is the CountryName with missing CountryCode value.
#But, the table is missing the rest of the data for Kosovo as well.
#Since the data for Kosovo is not available at this point, for the purpose of this activity, 
#the row for Kosovo can be excluded from this analysis.
# Next step - remove the row for Kosovo from the table.

# %%
data1=data[data.CountryCode.notnull()]
#data1

# %%
#data1.describe()

# %%
#data1.info()

# %%
#For the years 1991-93, data is available for less than 100 countries.
#For the year 1994-95, data ia available for less than 200 countries.
#For the purpose of this exercise, we will consider data from the years 1996-2014.
#Remove the columns for the years 1991 to 1995

# %%
#We will start with replacing all the null values with 0

# %%
#We also see that none of the countries have data provided for all the 24 years from 1991 to 2014

# %%
data2=data1[data1.2011.notnull()]
# Out:
#   File "<ipython-input-71-2fbf075d093b>", line 1
#     data2=data1[data1.2011.notnull()]
#                          ^
# SyntaxError: invalid syntax

# %%
data.head()
# Out:
#    CountryName CountryCode  1991  1992  1993  1994   1995   1996   1997  \
# 0        Aruba         ABW   NaN   NaN   NaN   NaN    NaN  2.768    NaN
# 1      Andorra         AND   NaN   NaN   NaN   NaN    NaN  1.527  3.050
# 2  Afghanistan         AFG   NaN   NaN   NaN   NaN    NaN    NaN    NaN
# 3       Angola         AGO   NaN   NaN   NaN   NaN    NaN  0.001  0.006
# 4      Albania         ALB   NaN   NaN   NaN   NaN  0.011  0.032  0.049
#
#     1998  ...      2005    2006    2007   2008   2009  2010    2011    2012  \
# 0    NaN  ...    25.400  28.000  30.900  52.00  58.00    62  69.000  74.000
# 1  6.886  ...    37.606  48.937  70.870  70.04  78.53    81  81.000  86.434
# 2    NaN  ...     1.224   2.107   1.900   1.84   3.55     4   5.000   5.455
# 3  0.018  ...     1.143   1.908   3.200   4.60   6.00    10  14.776  16.937
# 4  0.065  ...     6.044   9.610  15.036  23.86  41.20    45  49.000  54.656
#
#    2013   2014
# 0  78.9  83.78
# 1  94.0  95.90
# 2   5.9   6.39
# ...

# %%
import pandas as pd
try4 = pd.read_csv("internet_data_4.csv")
#try4

# %%
#try4.info()

# %%
try41=try4[try4.CountryCode.notnull()]

# %%
#try41.info()

# %%
#try41=np.array(try41)

# %%
try41.rename(columns={'1991':'Y1991'},inplace=True)
try41.rename(columns={'1992':'Y1992'},inplace=True)
try41.rename(columns={'1993':'Y1993'},inplace=True)
try41.rename(columns={'1994':'Y1994'},inplace=True)
try41.rename(columns={'1995':'Y1995'},inplace=True)
try41.rename(columns={'1996':'Y1996'},inplace=True)
try41.rename(columns={'1997':'Y1997'},inplace=True)
try41.rename(columns={'1998':'Y1998'},inplace=True)
try41.rename(columns={'1999':'Y1999'},inplace=True)
try41.rename(columns={'2000':'Y2000'},inplace=True)
try41.rename(columns={'2001':'Y2001'},inplace=True)
try41.rename(columns={'2002':'Y2002'},inplace=True)
try41.rename(columns={'2003':'Y2003'},inplace=True)
try41.rename(columns={'2004':'Y2004'},inplace=True)
try41.rename(columns={'2005':'Y2005'},inplace=True)
try41.rename(columns={'2006':'Y2006'},inplace=True)
try41.rename(columns={'2007':'Y2007'},inplace=True)
try41.rename(columns={'2008':'Y2008'},inplace=True)
try41.rename(columns={'2009':'Y2009'},inplace=True)
try41.rename(columns={'2010':'Y2010'},inplace=True)
try41.rename(columns={'2011':'Y2011'},inplace=True)
try41.rename(columns={'2012':'Y2012'},inplace=True)
try41.rename(columns={'2013':'Y2013'},inplace=True)
try41.rename(columns={'2014':'Y2014'},inplace=True)

# %%
try41[0:1]
# Out:
#   CountryName CountryCode  Y1991  Y1992  Y1993  Y1994  Y1995  Y1996  Y1997  \
# 0       Aruba         ABW    NaN    NaN    NaN    NaN    NaN  2.768    NaN
#
#    Y1998  ...    Y2005  Y2006  Y2007  Y2008  Y2009  Y2010  ABCD  Y2012  Y2013  \
# 0    NaN  ...     25.4     28   30.9     52     58     62    69     74   78.9
#
#    Y2014
# 0  83.78
#
# [1 rows x 26 columns]

# %%
#try41.rename(columns={'ABCD':'Y2011'},inplace=True)
#try41.info()

# %%
table1=try41[['CountryName','CountryCode','Y1996','Y1997','Y1998','Y1999','Y2000','Y2001','Y2002','Y2003','Y2004','Y2005','Y2006','Y2007','Y2008','Y2009','Y2010','Y2011','Y2012','Y2013','Y2014']]
table1
# Out:
#                         CountryName CountryCode   Y1996   Y1997   Y1998  \
# 0                             Aruba         ABW   2.768     NaN     NaN
# 1                           Andorra         AND   1.527   3.050   6.886
# 2                       Afghanistan         AFG     NaN     NaN     NaN
# 3                            Angola         AGO   0.001   0.006   0.018
# 4                           Albania         ALB   0.032   0.049   0.065
# 5                        Arab World         ARB   0.038   0.131   0.262
# 6              United Arab Emirates         ARE   0.375   3.296   6.908
# 7                         Argentina         ARG   0.142   0.280   0.831
# 8                           Armenia         ARM   0.095   0.112   0.129
# 9                    American Samoa         ASM     NaN     NaN     NaN
# 10              Antigua and Barbuda         ATG   2.858   3.481   4.072
# 11                        Australia         AUS   3.275  16.369  30.813
# ...

# %%
#try42=np.array(try41)
#try43=try42.transpose()
#try43
